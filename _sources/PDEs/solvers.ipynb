# %% [markdown]
# Iterative Solvers
# ===
#
# So far we have used direct solvers to solve the linear system of equations. Although a direct solver can profit from the sparse matrix, it's arithmetic complexity is sub-optimal. For large-scale problems iterative solvers are a must.
#
# The conjugate gradient (cg) method is the standard method for symmetric and positive definite matrices. It's convergence rate depends on a preconditioner, what is a cheap approximative inverse to the matrix.

# %%
from ngsolve import *
from ngsolve.webgui import Draw
from netgen.webgui import Draw as DrawGeo

# %% [markdown]
# We generate a 3D geometry and mesh using the OCC constructive solid geometry (CSG) modeler:

# %%
from netgen.occ import *
cube = Box((0,0,0),(1,1,1))
cyl = Cylinder((0,0.5,0.5),X, r=0.2, h=1)
cube.faces.name = "outer"
cyl.faces.name = "cyl"
shape = cube-cyl
DrawGeo(shape);
# Out:
# WebGuiWidget(layout=Layout(height='50vh', width='100%'), value={'ngsolve_version': 'Netgen x.x', 'mesh_dim': 3…

# %%
ngmesh = OCCGeometry(shape).GenerateMesh(maxh=0.1)
for l in range(0):
    ngmesh.Refine()
mesh = Mesh(ngmesh)
mesh.Curve(3)
Draw (mesh);
# Out:
# Highest entry in topology hierarchy:
# 1 solid(s)
#  set global mesh
#  Face 1 / 7 (parameter space projection)
#  Surface meshing done
#  0 illegal triangles
#  Face 2 / 7 (parameter space projection)
#  Surface meshing done
#  0 illegal triangles
#  Face 3 / 7 (parameter space projection)
#  Surface meshing done
#  0 illegal triangles
#  Face 4 / 7 (parameter space projection)
#  Surface meshing done
#  0 illegal triangles
#  Face 5 / 7 (parameter space projection)
#  Surface meshing done
#  0 illegal triangles
#  Face 6 / 7 (parameter space projection)
#  Surface meshing done
#  0 illegal triangles
#  Face 7 / 7 (parameter space projection)
#  Surface meshing done
#  0 illegal triangles
#  Optimization step 0
#  Edgeswapping, topological
#  Smoothing
#  Combine improve
#  Smoothing
#  Edgeswapping, metric
#  Smoothing
#  Combine improve
#  Smoothing
#  Edgeswapping, metric
#  Smoothing
#  Combine improve
#  Smoothing
#  Optimization step 0
#  Edgeswapping, topological
#  Smoothing
#  Combine improve
#  Smoothing
#  Edgeswapping, metric
#  Smoothing
#  Combine improve
#  Smoothing
#  Edgeswapping, metric
#  Smoothing
#  Combine improve
#  Smoothing
#  Optimization step 0
#  Edgeswapping, topological
#  Smoothing
#  Combine improve
#  Smoothing
#  Edgeswapping, metric
#  Smoothing
#  Combine improve
#  Smoothing
#  Edgeswapping, metric
#  Smoothing
#  Combine improve
#  Smoothing
#  Optimization step 0
#  Edgeswapping, topological
#  Smoothing
#  Combine improve
#  Smoothing
#  Edgeswapping, metric
#  Smoothing
#  Combine improve
#  Smoothing
#  Edgeswapping, metric
#  Smoothing
#  Combine improve
#  Smoothing
#  Optimization step 0
#  Edgeswapping, topological
#  Smoothing
#  Combine improve
#  Smoothing
#  Edgeswapping, metric
#  Smoothing
#  Combine improve
#  Smoothing
#  Edgeswapping, metric
#  Smoothing
#  Combine improve
#  Smoothing
#  Optimization step 0
#  Edgeswapping, topological
#  Smoothing
#  Combine improve
#  Smoothing
#  Edgeswapping, metric
#  Smoothing
#  Combine improve
#  Smoothing
#  Edgeswapping, metric
#  Smoothing
#  Combine improve
#  Smoothing
#  Optimization step 0
#  Edgeswapping, topological
#  Smoothing
#  Combine improve
#  Smoothing
#  Edgeswapping, metric
#  Smoothing
#  Combine improve
#  Smoothing
#  Edgeswapping, metric
#  Smoothing
#  Combine improve
#  Smoothing
#  Optimization step 1
#  Edgeswapping, topological
#  Smoothing
#  Combine improve
#  Smoothing
#  Edgeswapping, metric
#  Smoothing
#  Combine improve
#  Smoothing
#  Edgeswapping, metric
#  Smoothing
#  Combine improve
#  Smoothing
#  Optimization step 1
#  Edgeswapping, topological
#  Smoothing
#  Combine improve
#  Smoothing
#  Edgeswapping, metric
#  Smoothing
#  Combine improve
#  Smoothing
#  Edgeswapping, metric
#  Smoothing
#  Combine improve
#  Smoothing
#  Optimization step 1
#  Edgeswapping, topological
#  Smoothing
#  Combine improve
#  Smoothing
#  Edgeswapping, metric
#  Smoothing
#  Combine improve
#  Smoothing
#  Edgeswapping, metric
#  Smoothing
#  Combine improve
#  Smoothing
#  Optimization step 1
#  Edgeswapping, topological
#  Smoothing
#  Combine improve
#  Smoothing
#  Edgeswapping, metric
#  Smoothing
#  Combine improve
#  Smoothing
#  Edgeswapping, metric
#  Smoothing
#  Combine improve
#  Smoothing
#  Optimization step 1
#  Edgeswapping, topological
#  Smoothing
#  Combine improve
#  Smoothing
#  Edgeswapping, metric
#  Smoothing
#  Combine improve
#  Smoothing
#  Edgeswapping, metric
#  Smoothing
#  Combine improve
#  Smoothing
#  Optimization step 1
#  Edgeswapping, topological
#  Smoothing
#  Combine improve
#  Smoothing
#  Edgeswapping, metric
#  Smoothing
#  Combine improve
#  Smoothing
#  Edgeswapping, metric
#  Smoothing
#  Combine improve
#  Smoothing
#  Optimization step 1
#  Edgeswapping, topological
#  Smoothing
#  Combine improve
#  Smoothing
#  Edgeswapping, metric
#  Smoothing
#  Combine improve
#  Smoothing
#  Edgeswapping, metric
#  Smoothing
#  Combine improve
#  Smoothing
#  Optimization step 2
#  Edgeswapping, topological
#  Smoothing
#  Combine improve
#  Smoothing
#  Edgeswapping, metric
#  Smoothing
#  Combine improve
#  Smoothing
#  Edgeswapping, metric
#  Smoothing
#  Combine improve
#  Smoothing
#  Optimization step 2
#  Edgeswapping, topological
#  Smoothing
#  Combine improve
#  Smoothing
#  Edgeswapping, metric
#  Smoothing
#  Combine improve
#  Smoothing
#  Edgeswapping, metric
#  Smoothing
#  Combine improve
#  Smoothing
#  Optimization step 2
#  Edgeswapping, topological
#  Smoothing
#  Combine improve
#  Smoothing
#  Edgeswapping, metric
#  Smoothing
#  Combine improve
#  Smoothing
#  Edgeswapping, metric
#  Smoothing
#  Combine improve
#  Smoothing
#  Optimization step 2
#  Edgeswapping, topological
#  Smoothing
#  Combine improve
#  Smoothing
#  Edgeswapping, metric
#  Smoothing
#  Combine improve
#  Smoothing
#  Edgeswapping, metric
#  Smoothing
#  Combine improve
#  Smoothing
#  Optimization step 2
#  Edgeswapping, topological
#  Smoothing
#  Combine improve
#  Smoothing
#  Edgeswapping, metric
#  Smoothing
#  Combine improve
#  Smoothing
#  Edgeswapping, metric
#  Smoothing
#  Combine improve
#  Smoothing
#  Optimization step 2
#  Edgeswapping, topological
#  Smoothing
#  Combine improve
#  Smoothing
#  Edgeswapping, metric
#  Smoothing
#  Combine improve
#  Smoothing
#  Edgeswapping, metric
#  Smoothing
#  Combine improve
#  Smoothing
#  Optimization step 2
#  Edgeswapping, topological
#  Smoothing
#  Combine improve
#  Smoothing
#  Edgeswapping, metric
#  Smoothing
#  Combine improve
#  Smoothing
#  Edgeswapping, metric
#  Smoothing
#  Combine improve
#  Smoothing
#  1660 open elements
#  1660 open elements
#  Use internal rules
#  Delaunay meshing
#  number of points: 830
#  blockfill local h
#  number of points: 1370
# .
#  Points: 1370
#  Elements: 8372
#  Tree data entries per element: 1.5528
#  Tree nodes per element: 0.0309365
#  0 open elements
#  Num open: 0
#  free: 0, fixed: 8372
#  SwapImprove
#  0 swaps performed
#  Num open: 0
#  SwapImprove
#  0 swaps performed
#  Num open: 0
#  SwapImprove
#  0 swaps performed
#  Num open: 0
#  SwapImprove
#  0 swaps performed
#  Num open: 0
#  SwapImprove
#  0 swaps performed
#  Num open: 0
#  free: 0, fixed: 8372
#  SwapImprove
#  0 swaps performed
#  Num open: 0
#  SwapImprove
#  0 swaps performed
#  Num open: 0
#  SwapImprove
#  0 swaps performed
#  Num open: 0
#  SwapImprove
#  0 swaps performed
#  Num open: 0
#  SwapImprove
#  0 swaps performed
#  0 degenerated elements removed
#  Remove intersecting
#  Remove outer
#  tables filled
#  outer removed
#  1660 open elements
#  1370 points, 6104 elements
#  0 open elements
#  Check subdomain 1 / 1
#  0 open elements
#  Remove Illegal Elements
#  0 illegal tets
#  Volume Optimization
#  CombineImprove
#  8304 edges
#  137 edges with improvement
#  59 elements combined
#  ImproveMesh
#  Total badness = 9772.66
#  Total badness = 8789.54
#  SplitImprove
#  7755 edges
#  0 edges with improvement
#  0 splits performed
#  0 elements split
#  ImproveMesh
#  Total badness = 8789.54
#  Total badness = 8678.72
#  SwapImprove
#  296 swaps performed
#  SwapImprove2
#  0 swaps performed
#  ImproveMesh
#  Total badness = 7778.1
#  Total badness = 7574.35
#  CombineImprove
#  7527 edges
#  61 edges with improvement
#  42 elements combined
#  ImproveMesh
#  Total badness = 7001.6
#  Total badness = 6940.44
#  SplitImprove
#  7171 edges
#  0 edges with improvement
#  0 splits performed
#  0 elements split
#  ImproveMesh
#  Total badness = 6940.44
#  Total badness = 6932.04
#  SwapImprove
#  177 swaps performed
#  SwapImprove2
#  0 swaps performed
#  ImproveMesh
#  Total badness = 6618.46
#  Total badness = 6528.27
#  CombineImprove
#  7084 edges
#  23 edges with improvement
#  18 elements combined
#  ImproveMesh
#  Total badness = 6329.53
#  Total badness = 6307.24
#  SplitImprove
#  6939 edges
#  0 edges with improvement
#  0 splits performed
#  0 elements split
#  ImproveMesh
#  Total badness = 6307.24
#  Total badness = 6304.53
#  SwapImprove
#  91 swaps performed
#  SwapImprove2
#  0 swaps performed
#  ImproveMesh
#  Total badness = 6203.39
#  Total badness = 6155.89
#  set global mesh
#  Update mesh topology
#  Update edges
#  Update faces
#  Update clusters
#  Curve elements, order = 3
#  Update clusters
#  Curving edges
#  Curving faces
# WebGuiWidget(layout=Layout(height='50vh', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.23…

# %%
fes = H1(mesh, order=3, dirichlet="outer", wb_withoutedges=True)
print ("we have", fes.ndof, "unknowns")
u = fes.TrialFunction()
v = fes.TestFunction()

a = BilinearForm(fes)
a += grad(u)*grad(v)*dx

f = LinearForm(fes)
f += v*dx

# c = Preconditioner(a, "direct", inverse="sparsecholesky")
c = Preconditioner(a, "local")
# c = Preconditioner(a, "bddc")

gfu = GridFunction(fes)
# Out:
# we have 25575 unknowns

# %% [markdown]
# assemble system and setup preconditioner in parallel:

# %%
ngsglobals.msg_level=5
with TaskManager():
    a.Assemble()
    f.Assemble()
# Out:
# assemble VOL element 4833/4833
# assemble VOL element 4833/4833

# %% [markdown]
# solve the system using the preconditioned conjugate gradient method:

# %%
from ngsolve.krylovspace import CGSolver

with TaskManager():
    inv = CGSolver(mat=a.mat, pre=c.mat, printrates=True, maxiter=400)
    gfu.vec.data = inv * f.vec
# Out:
# CG iteration 1, residual = 0.04653198884871723
# CG iteration 2, residual = 0.05290163957022697
# CG iteration 3, residual = 0.05573659220484592
# CG iteration 4, residual = 0.04548134207412587
# CG iteration 5, residual = 0.03057360298928957
# CG iteration 6, residual = 0.02444369204273861
# CG iteration 7, residual = 0.019620412344585666
# CG iteration 8, residual = 0.014013388449121174
# CG iteration 9, residual = 0.009951850338604361
# CG iteration 10, residual = 0.0077815585449014695
# CG iteration 11, residual = 0.006915536818293857
# CG iteration 12, residual = 0.006452419556672611
# CG iteration 13, residual = 0.00660768482216925
# CG iteration 14, residual = 0.0071333821715744775
# CG iteration 15, residual = 0.00693951716546615
# CG iteration 16, residual = 0.006009073401378995
# CG iteration 17, residual = 0.0047473102005996535
# CG iteration 18, residual = 0.0035891514262892713
# CG iteration 19, residual = 0.0026226587476950933
# CG iteration 20, residual = 0.0019440920495371243
# CG iteration 21, residual = 0.0015404115938269446
# CG iteration 22, residual = 0.001371287327070212
# CG iteration 23, residual = 0.0012714095631680225
# CG iteration 24, residual = 0.0011640848857961319
# CG iteration 25, residual = 0.0010429843312903728
# CG iteration 26, residual = 0.0009024933934698809
# CG iteration 27, residual = 0.0007414082894248604
# CG iteration 28, residual = 0.0005772901322718841
# CG iteration 29, residual = 0.0004429520312541485
# CG iteration 30, residual = 0.00036000933814321433
# CG iteration 31, residual = 0.0002933075611285161
# CG iteration 32, residual = 0.00023773834225189195
# CG iteration 33, residual = 0.0001953040635824894
# CG iteration 34, residual = 0.00016174916952050965
# CG iteration 35, residual = 0.00013262800652206333
# CG iteration 36, residual = 0.00010884962689445952
# CG iteration 37, residual = 9.21146302124051e-05
# CG iteration 38, residual = 7.992859954865691e-05
# CG iteration 39, residual = 6.932236312661643e-05
# CG iteration 40, residual = 6.10514552810426e-05
# CG iteration 41, residual = 5.308041358214539e-05
# CG iteration 42, residual = 4.45311863930749e-05
# CG iteration 43, residual = 3.7300131601007176e-05
# CG iteration 44, residual = 3.0282697051605752e-05
# CG iteration 45, residual = 2.3831449582923606e-05
# CG iteration 46, residual = 1.9027564100131755e-05
# CG iteration 47, residual = 1.4989722940381187e-05
# CG iteration 48, residual = 1.2051751726567821e-05
# CG iteration 49, residual = 1.0036675670741098e-05
# CG iteration 50, residual = 8.500450034397648e-06
# CG iteration 51, residual = 7.712027722934203e-06
# CG iteration 52, residual = 7.106759877456036e-06
# CG iteration 53, residual = 6.49797686146154e-06
# CG iteration 54, residual = 5.848400724377334e-06
# CG iteration 55, residual = 4.885904149699578e-06
# CG iteration 56, residual = 3.865633648296206e-06
# CG iteration 57, residual = 2.896699538375704e-06
# CG iteration 58, residual = 2.144308386081926e-06
# CG iteration 59, residual = 1.6425100688733967e-06
# CG iteration 60, residual = 1.3217128913072731e-06
# CG iteration 61, residual = 1.1459968387115522e-06
# CG iteration 62, residual = 1.0806116090127971e-06
# CG iteration 63, residual = 1.040005645997899e-06
# CG iteration 64, residual = 9.756436886499452e-07
# CG iteration 65, residual = 8.473357693622441e-07
# CG iteration 66, residual = 6.795562550826937e-07
# CG iteration 67, residual = 5.140481459626675e-07
# CG iteration 68, residual = 3.86268151197959e-07
# CG iteration 69, residual = 3.019194897301137e-07
# CG iteration 70, residual = 2.4332870703595556e-07
# CG iteration 71, residual = 2.054247517870693e-07
# CG iteration 72, residual = 1.8169282679763146e-07
# CG iteration 73, residual = 1.6764809209370944e-07
# CG iteration 74, residual = 1.51609989238374e-07
# CG iteration 75, residual = 1.3274291131934133e-07
# CG iteration 76, residual = 1.1376851134319418e-07
# CG iteration 77, residual = 9.348042905956924e-08
# CG iteration 78, residual = 7.696485935980805e-08
# CG iteration 79, residual = 6.246618096147024e-08
# CG iteration 80, residual = 5.1385333180448256e-08
# CG iteration 81, residual = 4.259756317906542e-08
# CG iteration 82, residual = 3.519979623419134e-08
# CG iteration 83, residual = 2.911725289981067e-08
# CG iteration 84, residual = 2.4158477605817502e-08
# CG iteration 85, residual = 2.0132346454077885e-08
# CG iteration 86, residual = 1.70684830312062e-08
# CG iteration 87, residual = 1.4731707574092288e-08
# CG iteration 88, residual = 1.2833849311179756e-08
# CG iteration 89, residual = 1.1350323665509797e-08
# CG iteration 90, residual = 1.0038214623884977e-08
# CG iteration 91, residual = 8.817054991274538e-09
# CG iteration 92, residual = 7.500038688491378e-09
# CG iteration 93, residual = 5.983569252039065e-09
# CG iteration 94, residual = 4.656589092527947e-09
# CG iteration 95, residual = 3.598716826158517e-09
# CG iteration 96, residual = 2.818142043634036e-09
# CG iteration 97, residual = 2.2849964199926687e-09
# CG iteration 98, residual = 1.993526114215955e-09
# CG iteration 99, residual = 1.865959916177062e-09
# CG iteration 100, residual = 1.8041042138515255e-09
# CG iteration 101, residual = 1.6852720181248916e-09
# CG iteration 102, residual = 1.4900290046940742e-09
# CG iteration 103, residual = 1.2209783288781794e-09
# CG iteration 104, residual = 9.386330089331464e-10
# CG iteration 105, residual = 6.902054553938175e-10
# CG iteration 106, residual = 5.118398296310405e-10
# CG iteration 107, residual = 3.908862772152899e-10
# CG iteration 108, residual = 3.147901661840904e-10
# CG iteration 109, residual = 2.700003634428327e-10
# CG iteration 110, residual = 2.455700400647767e-10
# CG iteration 111, residual = 2.342110863069465e-10
# CG iteration 112, residual = 2.1699813640697957e-10
# CG iteration 113, residual = 1.8663229024604182e-10
# CG iteration 114, residual = 1.5544544625760207e-10
# CG iteration 115, residual = 1.2310043188756667e-10
# CG iteration 116, residual = 9.523370805651347e-11
# CG iteration 117, residual = 7.300021742613187e-11
# CG iteration 118, residual = 5.640063320313975e-11
# CG iteration 119, residual = 4.5202816693804763e-11
# CG iteration 120, residual = 3.777789049147571e-11
# CG iteration 121, residual = 3.2740195691652495e-11
# CG iteration 122, residual = 2.976436481173347e-11
# CG iteration 123, residual = 2.75282760417649e-11
# CG iteration 124, residual = 2.564342794357078e-11
# CG iteration 125, residual = 2.3221257678211097e-11
# CG iteration 126, residual = 1.9674247114255535e-11
# CG iteration 127, residual = 1.585603591782193e-11
# CG iteration 128, residual = 1.2330402086013685e-11
# CG iteration 129, residual = 9.085646293738382e-12
# CG iteration 130, residual = 6.826877081636001e-12
# CG iteration 131, residual = 5.385226808306317e-12
# CG iteration 132, residual = 4.591570166892799e-12
# CG iteration 133, residual = 4.131009375790045e-12
# CG iteration 134, residual = 3.970872572698204e-12
# CG iteration 135, residual = 3.850272554642981e-12
# CG iteration 136, residual = 3.4949528681159548e-12
# CG iteration 137, residual = 2.9474794145675678e-12
# CG iteration 138, residual = 2.269866560246701e-12
# CG iteration 139, residual = 1.6529446955168125e-12
# CG iteration 140, residual = 1.2028634020098836e-12
# CG iteration 141, residual = 8.661612398531565e-13
# CG iteration 142, residual = 6.79617933464566e-13
# CG iteration 143, residual = 5.770591656550165e-13
# CG iteration 144, residual = 5.240103832871209e-13
# CG iteration 145, residual = 5.068027403716324e-13
# CG iteration 146, residual = 4.870185528706233e-13
# CG iteration 147, residual = 4.389381903866775e-13
# CG iteration 148, residual = 3.624789608470229e-13
# CG iteration 149, residual = 2.7485624936029834e-13
# CG iteration 150, residual = 2.0100804173306114e-13
# CG iteration 151, residual = 1.4442068278475484e-13
# CG iteration 152, residual = 1.07997739285162e-13
# CG iteration 153, residual = 8.561620311898591e-14
# CG iteration 154, residual = 7.344583332742269e-14
# CG iteration 155, residual = 6.76771299619674e-14
# CG iteration 156, residual = 6.701662105191434e-14
# CG iteration 157, residual = 6.469973958210243e-14
# CG iteration 158, residual = 5.800032695399844e-14
# CG iteration 159, residual = 4.9070502399493454e-14
# CG iteration 160, residual = 3.856874982838848e-14

# %%
Draw (gfu);
# Out:
# WebGuiWidget(layout=Layout(height='50vh', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.23…
